# %% [markdown]
# ## Running Dalle Locally

# %%
# Pip installs
# !pip install -q dalle-mini
# !pip install -q git+https://github.com/patil-suraj/vqgan-jax.git

# %% [markdown]
# # Model References

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
# Model references

# dalle-mega
# DALLE_MODEL = "dalle-mini/dalle-mega"  # can be wandb artifact or 🤗 Hub or local folder or google bucket
DALLE_MODEL = '/home/robmulla/Repos/dalle-mega/'
DALLE_COMMIT_ID = None

# if the notebook crashes too often you can use dalle-mini instead by uncommenting below line
# DALLE_MODEL = "dalle-mini/dalle-mini/mini-1:v0"

# VQGAN model
VQGAN_REPO = "dalle-mini/vqgan_imagenet_f16_16384"
VQGAN_COMMIT_ID = "e93a26e7707683d349bf5d5c41c5b0ef69b677a9"

# %%
import jax

# check how many devices are available
jax.local_device_count()
# Out:
# 1

# %%
# Load models & tokenizer
from dalle_mini import DalleBart, DalleBartProcessor
from vqgan_jax.modeling_flax_vqgan import VQModel
from transformers import CLIPProcessor, FlaxCLIPModel

# Load dalle-mini
model, params = DalleBart.from_pretrained(
    DALLE_MODEL,
    revision=DALLE_COMMIT_ID, 
    dtype=jnp.float16, _do_init=False
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_48213/1972222864.py in <module>
#       8     DALLE_MODEL,
#       9     revision=DALLE_COMMIT_ID,
# ---> 10     dtype=jnp.float16, _do_init=False
#      11 )
#
# NameError: name 'jnp' is not defined

# %%
# Load VQGAN
vqgan, vqgan_params = VQModel.from_pretrained(
    VQGAN_REPO, revision=VQGAN_COMMIT_ID, _do_init=False
)

# %%
from flax.jax_utils import replicate

params = replicate(params)
vqgan_params = replicate(vqgan_params)
# Out:
# 2022-07-03 15:41:36.005442: W external/org_tensorflow/tensorflow/core/common_runtime/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 192.0KiB (rounded to 196608)requested by op
# 2022-07-03 15:41:36.005652: W external/org_tensorflow/tensorflow/core/common_runtime/bfc_allocator.cc:491] ****************************************************************************************************
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# /tmp/ipykernel_44376/2660751907.py in <module>
#       1 from flax.jax_utils import replicate
#       2
# ----> 3 params = replicate(params)
#       4 vqgan_params = replicate(vqgan_params)
#
# ~/anaconda3/envs/kaggle2/lib/python3.8/site-packages/flax/jax_utils.py in replicate(tree, devices)
#      54   """
#      55   devices = devices or _pmap_device_order()
# ---> 56   return jax.device_put_replicated(tree, devices)
#      57
#      58
#
# ~/anaconda3/envs/kaggle2/lib/python3.8/site-packages/jax/_src/api.py in device_put_replicated(x, devices)
#    2917
#    2918   with config_explicit_device_put_scope():
# -> 2919     return tree_map(_device_put_replicated, x)
#    2920
#    2921
#
# ~/anaconda3/envs/kaggle2/lib/python3.8/site-packages/jax/_src/tree_util.py in tree_map(f, tree, is_leaf, *rest)
#     194   leaves, treedef = tree_flatten(tree, is_leaf)
#     195   all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
# --> 196   return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#     197
#     198 def tree_multimap(*args, **kwargs):
#
# ~/anaconda3/envs/kaggle2/lib/python3.8/site-packages/jax/_src/tree_util.py in <genexpr>(.0)
#     194   leaves, treedef = tree_flatten(tree, is_leaf)
#     195   all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
# --> 196   return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#     197
#     198 def tree_multimap(*args, **kwargs):
#
# ~/anaconda3/envs/kaggle2/lib/python3.8/site-packages/jax/_src/api.py in _device_put_replicated(x)
#    2905     assert (isinstance(aval, ShapedArray) and
#    2906             len(xla.aval_to_xla_shapes(aval)) == 1)
# -> 2907     buf, = dispatch.device_put(x, devices[0])
#    2908     rest_bufs = [buf.copy_to_device(d) for d in devices[1:]]
#    2909     if config.jax_array:
#
# ~/anaconda3/envs/kaggle2/lib/python3.8/site-packages/jax/_src/dispatch.py in device_put(x, device)
#     976   x = xla.canonicalize_dtype(x)
#     977   try:
# --> 978     return device_put_handlers[type(x)](x, device)
#     979   except KeyError as err:
#     980     raise TypeError(f"No device_put handler for type: {type(x)}") from err
#
# ~/anaconda3/envs/kaggle2/lib/python3.8/site-packages/jax/_src/dispatch.py in _device_put_device_array(x, device)
#    1006
#    1007 def _device_put_device_array(x: Union[device_array.DeviceArrayProtocol, device_array._DeviceArray], device: Optional[Device]):
# -> 1008   x = _copy_device_array_to_device(x, device)
#    1009   return (x.device_buffer,)
#    1010 for t in device_array.device_array_types:
#
# ~/anaconda3/envs/kaggle2/lib/python3.8/site-packages/jax/_src/dispatch.py in _copy_device_array_to_device(x, device)
#    1032     # buffers from different XLA backends are passed through the host.
#    1033     backend = xb.get_device_backend(device)
# -> 1034     moved_buf = backend.buffer_from_pyval(x.device_buffer.to_py(), device)
#    1035   return device_array.make_device_array(x.aval, device, moved_buf)
#    1036
#
# XlaRuntimeError: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 196608 bytes.

# %%
from functools import partial

# model inference
@partial(jax.pmap, axis_name="batch", static_broadcasted_argnums=(3, 4, 5, 6))
def p_generate(
    tokenized_prompt, key, params, top_k, top_p, temperature, condition_scale
):
    return model.generate(
        **tokenized_prompt,
        prng_key=key,
        params=params,
        top_k=top_k,
        top_p=top_p,
        temperature=temperature,
        condition_scale=condition_scale,
    )


# decode image
@partial(jax.pmap, axis_name="batch")
def p_decode(indices, params):
    return vqgan.decode_code(indices, params=params)

# %%
import random

# create a random key
seed = random.randint(0, 2**32 - 1)
key = jax.random.PRNGKey(seed)

# %%
from dalle_mini import DalleBartProcessor

processor = DalleBartProcessor.from_pretrained(DALLE_MODEL, revision=DALLE_COMMIT_ID)
# Out:
# wandb: Downloading large artifact mini-1:v0, 1673.43MB. 7 files... Done. 0:0:0

# %%
prompts = ["a marshmello in new york", "a doctor boxing with a kangaroo"]

# %%
tokenized_prompts = processor(prompts)

# %%
tokenized_prompt = replicate(tokenized_prompts)

# %%
# number of predictions per prompt
n_predictions = 1

# We can customize generation parameters (see https://huggingface.co/blog/how-to-generate)
gen_top_k = None
gen_top_p = None
temperature = None
cond_scale = 10.0

# %%
from flax.training.common_utils import shard_prng_key
import numpy as np
from PIL import Image
from tqdm.notebook import trange

print(f"Prompts: {prompts}\n")
# generate images
images = []
for i in trange(max(n_predictions // jax.device_count(), 1)):
    # get a new key
    key, subkey = jax.random.split(key)
    # generate images
    encoded_images = p_generate(
        tokenized_prompt,
        shard_prng_key(subkey),
        params,
        gen_top_k,
        gen_top_p,
        temperature,
        cond_scale,
    )
    # remove BOS
    encoded_images = encoded_images.sequences[..., 1:]
    # decode images
    decoded_images = p_decode(encoded_images, vqgan_params)
    decoded_images = decoded_images.clip(0.0, 1.0).reshape((-1, 256, 256, 3))
    for decoded_img in decoded_images:
        img = Image.fromarray(np.asarray(decoded_img * 255, dtype=np.uint8))
        images.append(img)
        display(img)
        print()
# Out:
# Prompts: ['a marshmello in new york', 'a doctor boxing with a kangaroo']
#   0%|          | 0/1 [00:00<?, ?it/s]
# /home/robmulla/anaconda3/envs/kaggle2/lib/python3.8/site-packages/jax/_src/ops/scatter.py:87: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=float16 to dtype=float32. In future JAX releases this will result in an error.
#   warnings.warn("scatter inputs have incompatible types: cannot safely cast "
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>
