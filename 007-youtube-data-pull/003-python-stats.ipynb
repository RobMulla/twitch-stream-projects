# %% [markdown]
# # Top Python Youtube Video

# %%
# %load_ext lab_black

# %%
from googleapiclient.discovery import build
import pandas as pd
import os
from tqdm import tqdm
import seaborn as sns
import matplotlib.pylab as plt
import sys

sys.path.append("../src/")
from yt_pullers import get_search_results, get_video_stats

# %%
youTubeApiKey = # Read here
youtube = build("youtube", "v3", developerKey=youTubeApiKey)

# %%
# df = get_search_results("python", youtube)
df_python = get_video_stats(df, youtube)

# %%
top_50_channels = (
    df_python.groupby("channelTitle")["statistics.viewCount"]
    .sum()
    .sort_values(ascending=False)
    .head(50)
    .index
)

# %%
df_python["statistics.viewCount"].plot(kind="hist", bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_python.loc[df_python["statistics.viewCount"] < 100]
# Out:
#               kind      videoId playlistId channelId           publishedAt  \
# 486  youtube#video  cBWMcWd9vA4        NaN       NaN  2021-12-18T13:54:28Z
# 552  youtube#video  eIG5URsGDog        NaN       NaN  2021-12-18T02:55:42Z
# 607  youtube#video  FzzzoR8iMKQ        NaN       NaN  2021-12-18T17:17:22Z
# 617  youtube#video  WiaddU2wYNQ        NaN       NaN  2021-12-13T07:51:02Z
# 620  youtube#video  TIjWjiV7hec        NaN       NaN  2021-05-31T06:03:48Z
# 621  youtube#video  VIl_0GuzvDg        NaN       NaN  2021-12-18T18:27:52Z
# 635  youtube#video  c91VT_DkJ8U        NaN       NaN  2021-12-17T15:25:44Z
# 643  youtube#video  F8JWeo1lRmc        NaN       NaN  2021-12-18T08:04:56Z
# 644  youtube#video  uzRZ33YdN6U        NaN       NaN  2021-12-18T14:14:49Z
# 649  youtube#video  rOiymGbWhmw        NaN       NaN  2021-11-29T17:51:44Z
# 652  youtube#video  B__SMjE0iXo        NaN       NaN  2021-12-18T15:48:50Z
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 15))
sns.scatterplot(
    x="statistics.viewCount",
    y="statistics.likeCount",
    hue="channelTitle",
    data=df_python.query("channelTitle in @top_50_channels"),
)
# Out:
# <AxesSubplot:xlabel='statistics.viewCount', ylabel='statistics.likeCount'>
# /home/robmulla/anaconda3/envs/kaggle/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2361 (\N{DEVANAGARI LETTER HA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/robmulla/anaconda3/envs/kaggle/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Matplotlib currently does not support Devanagari natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/robmulla/anaconda3/envs/kaggle/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2367 (\N{DEVANAGARI VOWEL SIGN I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/robmulla/anaconda3/envs/kaggle/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2306 (\N{DEVANAGARI SIGN ANUSVARA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
