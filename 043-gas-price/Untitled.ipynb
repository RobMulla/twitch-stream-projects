# %% [markdown]
# # Gas Price Dataset

# %%
import pandas as pd
import requests

# %%
df = pd.read_html('E85 Prices.html')[1]

# %%
# res = requests.get('https://e85prices.com/default/ajaxGetStatesWithStations')

# %%
url = 'https://e85prices.com/prices/ajaxFrontPrices?draw=3&columns%5B0%5D%5Bdata%5D=price_e85&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=price_e10&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=price_spread&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=price_e0&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=false&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=formatted_date&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=username&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B7%5D%5Bdata%5D=station_name&columns%5B7%5D%5Bname%5D=&columns%5B7%5D%5Bsearchable%5D=true&columns%5B7%5D%5Borderable%5D=true&columns%5B7%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B7%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B8%5D%5Bdata%5D=city_name&columns%5B8%5D%5Bname%5D=&columns%5B8%5D%5Bsearchable%5D=true&columns%5B8%5D%5Borderable%5D=true&columns%5B8%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B8%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B9%5D%5Bdata%5D=state_name&columns%5B9%5D%5Bname%5D=&columns%5B9%5D%5Bsearchable%5D=true&columns%5B9%5D%5Borderable%5D=true&columns%5B9%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B9%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B10%5D%5Bdata%5D=phone&columns%5B10%5D%5Bname%5D=&columns%5B10%5D%5Bsearchable%5D=true&columns%5B10%5D%5Borderable%5D=false&columns%5B10%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B10%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B11%5D%5Bdata%5D=comments&columns%5B11%5D%5Bname%5D=&columns%5B11%5D%5Bsearchable%5D=true&columns%5B11%5D%5Borderable%5D=false&columns%5B11%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B11%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=4&order%5B0%5D%5Bdir%5D=desc&start=0&length=25&search%5Bvalue%5D=&search%5Bregex%5D=false&_=1657505667558'
url = 'https://e85prices.com/prices/ajaxFrontPrices?draw=2&columns%5B0%5D%5Bdata%5D=price_e85&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=price_e10&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=price_spread&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=price_e0&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=false&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=formatted_date&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=username&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B7%5D%5Bdata%5D=station_name&columns%5B7%5D%5Bname%5D=&columns%5B7%5D%5Bsearchable%5D=true&columns%5B7%5D%5Borderable%5D=true&columns%5B7%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B7%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B8%5D%5Bdata%5D=city_name&columns%5B8%5D%5Bname%5D=&columns%5B8%5D%5Bsearchable%5D=true&columns%5B8%5D%5Borderable%5D=true&columns%5B8%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B8%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B9%5D%5Bdata%5D=state_name&columns%5B9%5D%5Bname%5D=&columns%5B9%5D%5Bsearchable%5D=true&columns%5B9%5D%5Borderable%5D=true&columns%5B9%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B9%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B10%5D%5Bdata%5D=phone&columns%5B10%5D%5Bname%5D=&columns%5B10%5D%5Bsearchable%5D=true&columns%5B10%5D%5Borderable%5D=false&columns%5B10%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B10%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B11%5D%5Bdata%5D=comments&columns%5B11%5D%5Bname%5D=&columns%5B11%5D%5Bsearchable%5D=true&columns%5B11%5D%5Borderable%5D=false&columns%5B11%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B11%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=4&order%5B0%5D%5Bdir%5D=desc&start=0&length=100&search%5Bvalue%5D=&search%5Bregex%5D=false&_=1657506224833'

# %%
url = 'https://e85prices.com/prices/ajaxFrontPrices?draw=2&columns%5B0%5D%5Bdata%5D=price_e85&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=price_e10&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=price_spread&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=price_e0&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=false&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=formatted_date&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=username&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B7%5D%5Bdata%5D=station_name&columns%5B7%5D%5Bname%5D=&columns%5B7%5D%5Bsearchable%5D=true&columns%5B7%5D%5Borderable%5D=true&columns%5B7%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B7%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B8%5D%5Bdata%5D=city_name&columns%5B8%5D%5Bname%5D=&columns%5B8%5D%5Bsearchable%5D=true&columns%5B8%5D%5Borderable%5D=true&columns%5B8%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B8%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B9%5D%5Bdata%5D=state_name&columns%5B9%5D%5Bname%5D=&columns%5B9%5D%5Bsearchable%5D=true&columns%5B9%5D%5Borderable%5D=true&columns%5B9%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B9%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B10%5D%5Bdata%5D=phone&columns%5B10%5D%5Bname%5D=&columns%5B10%5D%5Bsearchable%5D=true&columns%5B10%5D%5Borderable%5D=false&columns%5B10%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B10%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B11%5D%5Bdata%5D=comments&columns%5B11%5D%5Bname%5D=&columns%5B11%5D%5Bsearchable%5D=true&columns%5B11%5D%5Borderable%5D=false&columns%5B11%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B11%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=4&order%5B0%5D%5Bdir%5D=desc&start=0&length=500&search%5Bvalue%5D=&search%5Bregex%5D=false&_=1657506224833'

# %%
# url = 'https://e85prices.com/prices/ajaxFrontPrices?draw=3&columns%5B0%5D%5Bdata%5D=price_e85&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true'
res = requests.get(url)

# %%
# # url = 'https://e85prices.com/prices/ajaxFrontPrices?draw=3&columns%5B0%5D%5Bdata%5D=price_e85&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true'
# res = requests.get(url2)

# %%
# res.json()

# %%
df = pd.DataFrame(res.json()['data'])

# %%
pd.set_option('display.max_columns', 500)

# %%
df['state_name'].nunique()
# Out:
# 33

# %%
states = {"1":{"id":"31","state":"Alabama","state_short":"alabama"},"2":{"id":"23","state":"Arizona","state_short":"arizona"},"3":{"id":"27","state":"Arkansas","state_short":"arkansas"},"4":{"id":"15","state":"California","state_short":"california"},"5":{"id":"18","state":"Colorado","state_short":"colorado"},"6":{"id":"43","state":"Connecticut","state_short":"connecticut"},"7":{"id":"45","state":"Delaware","state_short":"delaware"},"8":{"id":"51","state":"District-of-Columbia","state_short":"district-of-columbia"},"9":{"id":"33","state":"Florida","state_short":"florida"},"10":{"id":"32","state":"Georgia","state_short":"georgia"},"11":{"id":"2","state":"Idaho","state_short":"idaho"},"12":{"id":"12","state":"Illinois","state_short":"illinois"},"13":{"id":"13","state":"Indiana","state_short":"indiana"},"14":{"id":"11","state":"Iowa","state_short":"iowa"},"15":{"id":"20","state":"Kansas","state_short":"kansas"},"16":{"id":"22","state":"Kentucky","state_short":"kentucky"},"17":{"id":"28","state":"Louisiana","state_short":"louisiana"},"18":{"id":"35","state":"Maryland","state_short":"maryland"},"19":{"id":"41","state":"Massachusetts","state_short":"massachusetts"},"20":{"id":"7","state":"Michigan","state_short":"michigan"},"21":{"id":"5","state":"Minnesota","state_short":"minnesota"},"22":{"id":"29","state":"Mississippi","state_short":"mississippi"},"23":{"id":"21","state":"Missouri","state_short":"missouri"},"24":{"id":"3","state":"Montana","state_short":"montana"},"25":{"id":"19","state":"Nebraska","state_short":"nebraska"},"26":{"id":"16","state":"Nevada","state_short":"nevada"},"27":{"id":"44","state":"New-Jersey","state_short":"new-jersey"},"28":{"id":"24","state":"New-Mexico","state_short":"new-mexico"},"29":{"id":"37","state":"New-York","state_short":"new-york"},"30":{"id":"47","state":"North-Carolina","state_short":"north-carolina"},"31":{"id":"4","state":"North-Dakota","state_short":"north-dakota"},"32":{"id":"14","state":"Ohio","state_short":"ohio"},"33":{"id":"26","state":"Oklahoma","state_short":"oklahoma"},"34":{"id":"8","state":"Oregon","state_short":"oregon"},"35":{"id":"36","state":"Pennsylvania","state_short":"pennsylvania"},"36":{"id":"48","state":"South-Carolina","state_short":"south-carolina"},"37":{"id":"10","state":"South-Dakota","state_short":"south-dakota"},"38":{"id":"30","state":"Tennessee","state_short":"tennessee"},"39":{"id":"25","state":"Texas","state_short":"texas"},"40":{"id":"17","state":"Utah","state_short":"utah"},"41":{"id":"46","state":"Virginia","state_short":"virginia"},"42":{"id":"1","state":"Washington","state_short":"washington"},"43":{"id":"34","state":"West-Virginia","state_short":"west-virginia"},"44":{"id":"6","state":"Wisconsin","state_short":"wisconsin"},"45":{"id":"9","state":"Wyoming","state_short":"wyoming"}}

# %%
df['state_name'].value_counts()
# Out:
# Michigan          91
# South-Dakota      58
# Wisconsin         55
# Minnesota         37
# Pennsylvania      28
# Illinois          17
# Ohio              16
# Nebraska          13
# Virginia           9
# Kansas             8
# Iowa               7
# California         4
# Arizona            4
# Missouri           4
# Colorado           4
# Texas              2
# Indiana            1
# South-Carolina     1
# Arkansas           1
# North-Dakota       1
# Kentucky           1
# Wyoming            1
# Tennessee          1
# North-Carolina     1
# Washington         1
# New-Mexico         1
# Louisiana          1
# Mississippi        1
# West-Virginia      1
# Georgia            1
# Florida            1
# New-York           1
# Oklahoma           1
# Name: state_name, dtype: int64

# %%
params = {
    "api_key" : mykey,
    "frequency": "annual",
    "data": [
        "value"
    ],
    "facets": {},
    "start": "1877",
    "end": "2021",
    # "sort": [
    #     {
    #         "column": "period",
    #         "direction": "desc"
    #     }
    # ],
    "offset": 0,
    "length": 5000,
    # "api-version": "2.0.2"
}

# %%
with open("api.key", "r") as keyfile:
    #read whole file to a string
    mykey = keyfile.read().strip('\n')

# %%
res = requests.get(f'https://api.eia.gov/v2/petroleum/sum/crdsnd/data', params)

# %%
params = {
    "api_key" : mykey,
    "frequency": "annual",
    "data": [
        "value"
    ],
    "facets": {},
    "start": "1990",
    "end": "2021",
    # "sort": [
    #     {
    #         "column": "period",
    #         "direction": "desc"
    #     }
    # ],
    "offset": 0,
    "length": 5000,
    # "api-version": "2.0.2"
}
res = requests.get('https://api.eia.gov/v2/petroleum/pri/gnd/data/', params)

# %%
res.json()
# Out:
# {'response': {'query execution': 0.158576326,
#   'count query execution': 0.225381376,
#   'total': 12712,
#   'dateFormat': 'YYYY',
#   'frequency': 'annual',
#   'data': [{'period': 2008,
#     'duoarea': 'NUS',
#     'area-name': 'U.S.',
#     'product': 'EPD2DM10',
#     'product-name': 'No 2 Diesel Low Sulfur (15-500 ppm)',
#     'process': 'PTE',
#     'process-name': 'Retail Sales',
#     'series': 'EMD_EPD2DM10_PTE_NUS_DPG',
#     'series-description': 'U.S. No 2 Diesel Low Sulfur (15-500 ppm) Retail Prices (Dollars per Gallon)'},
#    {'period': 2017,
#     'duoarea': 'R1Z',
#     'area-name': 'PADD 1C',
#     'product': 'EPD2DXL0',
#     'product-name': 'No 2 Diesel Low Sulfur (0-15 ppm)',
#     'process': 'PTE',
#     'process-name': 'Retail Sales',
#     'series': 'EMD_EPD2DXL0_PTE_R1Z_DPG',
#     'series-description': 'Lower Atlantic (PADD 1C) No 2 Diesel Ultra Low Sulfur (0-15 ppm) Retail Prices (Dollars per Gallon)'},
#    {'period': 2015,
#     'duoarea': 'R1Z',
# ...
