# %% [markdown]
# # Forbes top 100 Celebrities

# %%
import pandas as pd
import numpy as np

# %%
pd.read_html("https://www.amiannoying.com/(S(uivvfnjruahjsf51tlqwthjw))/collection.aspx?collection=78")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-378b4b49b7cf> in <module>
# ----> 1 pd.read_html("https://www.amiannoying.com/(S(uivvfnjruahjsf51tlqwthjw))/collection.aspx?collection=78")
#
# ~/anaconda3/envs/kaggle/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/envs/kaggle/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1111         na_values=na_values,
#    1112         keep_default_na=keep_default_na,
# -> 1113         displayed_only=displayed_only,
#    1114     )
#
# ...
